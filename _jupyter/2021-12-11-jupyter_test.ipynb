# %% [markdown]
# ### Test
# This is a test of jupyter notebooks.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.normal(0,1,100)
y = np.random.normal(0,1,100)

fig, axs = plt.subplots()
axs.scatter(x,y)
plt.show()
